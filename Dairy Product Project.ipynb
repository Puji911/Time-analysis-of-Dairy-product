# %% [markdown]
# #Import the Libraries and dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/dairy_dataset.csv")

# %%
df.sample(10)
# Out:
#          Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 3693    Telangana                   490.54              42     Large
# 3531      Haryana                   372.96              14    Medium
# 99        Gujarat                   305.81              66    Medium
# 3912        Delhi                    47.61              33    Medium
# 3297  West Bengal                   156.10              80    Medium
# 2332      Gujarat                   512.09              78     Small
# 1873  West Bengal                   821.99              55     Small
# 2518   Chandigarh                   755.65              46     Small
# 3783   Chandigarh                   257.16              87    Medium
# 4047        Delhi                   880.07              25    Medium
#
#             Date  Product ID Product Name           Brand  \
# 3693  2020-03-19           2       Butter    Mother Dairy
# 3531  2022-08-09          10         Ghee    Mother Dairy
# ...

# %%
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#          Date  Product ID Product Name                 Brand  \
# 0  2022-02-17           5    Ice Cream           Dodla Dairy
# 1  2021-12-01           1         Milk                  Amul
# 2  2022-02-28           4       Yogurt           Dodla Dairy
# 3  2019-06-09           3       Cheese  Britannia Industries
# 4  2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       2021-12-27
# ...

# %%
df.tail()
# Out:
#          Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 4320        Delhi                   748.71              89    Medium
# 4321    Jharkhand                   385.91              29     Large
# 4322   Chandigarh                   311.54              65     Small
# 4323  Maharashtra                   890.55              90     Small
# 4324    Rajasthan                   492.86              58     Large
#
#             Date  Product ID Product Name         Brand  Quantity (liters/kg)  \
# 4320  2022-02-24           6         Curd  Mother Dairy                554.90
# 4321  2022-05-14           4       Yogurt  Palle2patnam                818.33
# 4322  2020-01-05           6         Curd  Mother Dairy                583.56
# 4323  2022-10-25           6         Curd           Raj                  3.10
# 4324  2019-01-20           1         Milk  Mother Dairy                820.50
#
#       Price per Unit  ...  Production Date  Expiration Date  \
# ...

# %%
df.shape
# Out:
# (4325, 23)

# %%
df.isnull().sum()
# Out:
# Location                               0
# Total Land Area (acres)                0
# Number of Cows                         0
# Farm Size                              0
# Date                                   0
# Product ID                             0
# Product Name                           0
# Brand                                  0
# Quantity (liters/kg)                   0
# Price per Unit                         0
# Total Value                            0
# Shelf Life (days)                      0
# Storage Condition                      0
# Production Date                        0
# Expiration Date                        0
# Quantity Sold (liters/kg)              0
# Price per Unit (sold)                  0
# Approx. Total Revenue(INR)             0
# Customer Location                      0
# Sales Channel                          0
# Quantity in Stock (liters/kg)          0
# Minimum Stock Threshold (liters/kg)    0
# Reorder Quantity (liters/kg)           0
# ...

# %%
df.describe()
# Out:
#        Total Land Area (acres)  Number of Cows   Product ID  \
# count              4325.000000     4325.000000  4325.000000
# mean                503.483073       54.963699     5.509595
# std                 285.935061       26.111487     2.842979
# min                  10.170000       10.000000     1.000000
# 25%                 252.950000       32.000000     3.000000
# 50%                 509.170000       55.000000     6.000000
# 75%                 751.250000       77.000000     8.000000
# max                 999.530000      100.000000    10.000000
#
#        Quantity (liters/kg)  Price per Unit   Total Value  Shelf Life (days)  \
# count           4325.000000     4325.000000   4325.000000        4325.000000
# mean             500.652657       54.785938  27357.845411          29.127630
# std              288.975915       26.002815  21621.051594          30.272114
# min                1.170000       10.030000     42.516500           1.000000
# ...

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Date', 'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Location                                object
# Total Land Area (acres)                float64
# Number of Cows                           int64
# Farm Size                               object
# Date                                    object
# Product ID                               int64
# Product Name                            object
# Brand                                   object
# Quantity (liters/kg)                   float64
# Price per Unit                         float64
# Total Value                            float64
# Shelf Life (days)                        int64
# Storage Condition                       object
# Production Date                         object
# Expiration Date                         object
# Quantity Sold (liters/kg)                int64
# Price per Unit (sold)                  float64
# Approx. Total Revenue(INR)             float64
# Customer Location                       object
# Sales Channel                           object
# ...

# %%
df.duplicated().any()
# Out:
# False

# %%
df.describe(include='object')
# Out:
#        Location Farm Size        Date Product Name Brand Storage Condition  \
# count      4325      4325        4325         4325  4325              4325
# unique       15         3        1278           10    11                 5
# top       Delhi     Large  2021-01-28         Curd  Amul      Refrigerated
# freq        525      1462          11          479  1053              2459
#
#        Production Date Expiration Date Customer Location Sales Channel
# count             4325            4325              4325          4325
# unique            1405            1441                15             3
# top         2022-01-13      2019-07-27             Delhi        Retail
# freq                 9               9               499          1478

# %%
# Correlation matrix
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.histplot(data=df, x='Approx. Total Revenue(INR)')
plt.title('Distribution of Total Value')
plt.show()

# %% [markdown]
# The total revenue generated from the sales in Indian Rupees is approximately normal.

# %%
df['Brand'].value_counts()
# Out:
# Amul                    1053
# Mother Dairy            1010
# Raj                      685
# Sudha                    648
# Dodla Dairy              222
# Palle2patnam             211
# Dynamix Dairies          106
# Warana                   104
# Parag Milk Foods         102
# Passion Cheese            96
# Britannia Industries      88
# Name: Brand, dtype: int64

# %%
sns.countplot(x='Brand', data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# we observed that Amul is the highest brand >1000,compared to others.

# %%
sales_channel_counts = df['Sales Channel'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(sales_channel_counts.values, labels=sales_channel_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Sales Channels')
plt.show()

# %% [markdown]
# Compared to these dataset most of the items sold in retail as 34.2%,and in wholesale 34.1%,and online 31.7%. almost all are simillarly equal.

# %%
sns.barplot(x='Product Name',y='Quantity (liters/kg)',data=df)
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# From the above dataset curd is the highest with 500 above quantity

# %%
#To find how many products are in quantity in stock.
sns.countplot(x='Quantity in Stock (liters/kg)',data=df)
# Out:
# <Axes: xlabel='Quantity in Stock (liters/kg)', ylabel='count'>

# %%
df['Quantity in Stock (liters/kg)'].mean()
# Out:
# 252.06867052023122

# %% [markdown]
# By observing this the average products are in quantity in sold is 252.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Storage Condition', y='Quantity Sold (liters/kg)', data=df)
plt.xlabel('Storage Condition')
plt.ylabel('Quantity Sold (liters/kg)')
plt.title('Quantity Sold by Storage Condition')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# All the storage condition distributed in between the range of 0-400, and also some outliers are showned.

# %%
df['Product Name'].value_counts()
# Out:
# Curd          479
# Lassi         447
# Paneer        441
# Yogurt        437
# Buttermilk    435
# Butter        431
# Milk          429
# Ice Cream     423
# Ghee          402
# Cheese        401
# Name: Product Name, dtype: int64

# %%
top_one_value=df['Product Name'].sort_values(ascending=False).sum()
top_one_value
# Out:
# '... CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce CreamIce Cre
# ...

# %% [markdown]
# Yogurt product is top product compared to others.

# %%
#To find Total Value of Dairy Products by Location
sns.barplot(x='Location',y='Total Value',data=df)
plt.xlabel('Location')
plt.ylabel('Total Value')
plt.title('Total Value of Dairy Products by Location')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Total Value of Dairy Products are highest in Tamilnadu.

# %%
# To find in which sales channel has highest sales by location
sns.jointplot(x='Location',y='Sales Channel',data=df)
plt.xlabel('Location')
plt.ylabel('sales channel in location')
plt.xticks(rotation=80)
plt.show()

# %% [markdown]
# from the dataset Chandigarh and delhi has highest sales in retail.

# %%
#To check the count of products by storage condition
sns.countplot(x='Storage Condition', data=df)
plt.title('Count of Products by Storage Condition')
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# The count of products by storage condition is high in refigerated.

# %%
#To find which product is the highest in price
sns.barplot(x='Product Name',y='Price per Unit (sold)',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# We observing that similarly all are equal but a little bit difference Butter is the highest product sold per unit at 50-60 range

# %%
#To find the highest customer location
sns.countplot(x='Customer Location',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# By observing that most of the products are purchased in chandigarh and delhi, delhi is the highest compared to others,

# %%
df.columns
# Out:
# Index(['Location', 'Total Land Area (acres)', 'Number of Cows', 'Farm Size',
#        'Product ID', 'Product Name', 'Brand', 'Quantity (liters/kg)',
#        'Price per Unit', 'Total Value', 'Shelf Life (days)',
#        'Storage Condition', 'Production Date', 'Expiration Date',
#        'Quantity Sold (liters/kg)', 'Price per Unit (sold)',
#        'Approx. Total Revenue(INR)', 'Customer Location', 'Sales Channel',
#        'Quantity in Stock (liters/kg)', 'Minimum Stock Threshold (liters/kg)',
#        'Reorder Quantity (liters/kg)'],
#       dtype='object')

# %% [markdown]
# from th above we observe that quantity of products are in stock sold in range 0-200 has highest.

# %%
#check the production date and the product self life
sns.jointplot(x='Shelf Life (days)',y='Production Date',data=df)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the above dataset we observe The shelf life of a product is in between 0-20 days .In date 2022-01 has highest solds.

# %%
#The histogram displays the distribution of the shelf life of dairy products. It provides insights into the common shelf life range and the frequency of different shelf life values.
plt.figure(figsize=(8, 6))
sns.histplot(df['Shelf Life (days)'], bins=10)
plt.xlabel('Shelf Life (days)')
plt.ylabel('Count')
plt.title('Distribution of Shelf Life')
plt.show()

# %% [markdown]
# In this we observer that almost the products are sold in between 0-20 days.

# %%
sns.jointplot(x='Brand',y='Shelf Life (days)',data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The Amul product is the highest self life witin 10-20 days,and mother dairy product also similar to amul product.

# %%
#check which is the highest sales channel
sales_by_channel = df.groupby('Sales Channel')['Quantity Sold (liters/kg)'].sum().reset_index()
plt.figure(figsize=(10, 6))
sns.barplot(x='Sales Channel', y='Quantity Sold (liters/kg)', data=sales_by_channel)
plt.title('Sales Performance by Channel')
plt.xlabel('Sales Channel')
plt.ylabel('Total Quantity Sold (liters/kg)')
plt.show()

# %% [markdown]
# Compare sales performance across different channels by visualizing total quantity sold, retail and wholesale are almost equal.

# %%
sns.jointplot(x='Reorder Quantity (liters/kg)',y='Quantity in Stock (liters/kg)',data=df)

# %% [markdown]
# By observing that reorder products when the stock falls below the minimum thresholdis in between the range 150 is highest, and quantity in stock are almost high in 0

# %%
#Check minimum stock thresholds and reorder quantities to identify the products

# %%
minimum_stock_thresholds = df['Brand']
print(minimum_stock_thresholds)
# Out:
# 0                Dodla Dairy
# 1                       Amul
# 2                Dodla Dairy
# 3       Britannia Industries
# 4               Mother Dairy
#                 ...
# 4320            Mother Dairy
# 4321            Palle2patnam
# 4322            Mother Dairy
# 4323                     Raj
# 4324            Mother Dairy
# Name: Brand, Length: 4325, dtype: object

# %%
df['Reorder Quantity (liters/kg)']
# Out:
# 0        64.03
# 1       181.10
# 2       140.83
# 3        57.68
# 4        33.40
#          ...
# 4320     33.53
# 4321    114.37
# 4322    153.66
# 4323    160.84
# 4324    189.63
# Name: Reorder Quantity (liters/kg), Length: 4325, dtype: float64

# %%
print(restock_products[['Product ID', 'Product Name', 'Quantity in Stock (liters/kg)', 'Quantity to Reorder']])
# Out:
#       Product ID Product Name  Quantity in Stock (liters/kg)  \
# 4              8   Buttermilk                              2
# 10             4       Yogurt                             30
# 12             3       Cheese                             11
# 15             1         Milk                             43
# 25             9       Paneer                             41
# ...          ...          ...                            ...
# 4307           7        Lassi                             38
# 4310           1         Milk                              2
# 4316           8   Buttermilk                             22
# 4317           8   Buttermilk                             21
# 4323           6         Curd                              1
#
#       Quantity to Reorder
# 4                   33.40
# 10                 118.57
# 12                  69.19
# 15                  28.11
# 25                  70.40
# ...                   ...
# 4307               101.37
# ...

# %% [markdown]
# By doing this we conclude that  minimum stock thresholds and reorder quantities to identify the products

# %% [markdown]
# #Converting data into datetime

# %%
df['Date']=pd.to_datetime(df['Date'])
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#         Date  Product ID Product Name                 Brand  \
# 0 2022-02-17           5    Ice Cream           Dodla Dairy
# 1 2021-12-01           1         Milk                  Amul
# 2 2022-02-28           4       Yogurt           Dodla Dairy
# 3 2019-06-09           3       Cheese  Britannia Industries
# 4 2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       2021-12-27
# 1                687.48           42.61  ...       2021-10-03
# ...

# %%
df['Production Date']=pd.to_datetime(df['Production Date'])
df.head()
# Out:
#         Location  Total Land Area (acres)  Number of Cows Farm Size  \
# 0      Telangana                   310.84              96    Medium
# 1  Uttar Pradesh                    19.19              44     Large
# 2     Tamil Nadu                   581.69              24    Medium
# 3      Telangana                   908.00              89     Small
# 4    Maharashtra                   861.95              21    Medium
#
#         Date  Product ID Product Name                 Brand  \
# 0 2022-02-17           5    Ice Cream           Dodla Dairy
# 1 2021-12-01           1         Milk                  Amul
# 2 2022-02-28           4       Yogurt           Dodla Dairy
# 3 2019-06-09           3       Cheese  Britannia Industries
# 4 2020-12-14           8   Buttermilk          Mother Dairy
#
#    Quantity (liters/kg)  Price per Unit  ...  Production Date  \
# 0                222.40           85.72  ...       2021-12-27
# 1                687.48           42.61  ...       2021-10-03
# ...

# %%
df.set_index('Date',inplace=True)
df.set_index('Production Date',inplace=True)

# %%
df.head()
# Out:
#                       Location  Total Land Area (acres)  Number of Cows  \
# Production Date
# 2021-12-27           Telangana                   310.84              96
# 2021-10-03       Uttar Pradesh                    19.19              44
# 2022-01-14          Tamil Nadu                   581.69              24
# 2019-05-15           Telangana                   908.00              89
# 2020-10-17         Maharashtra                   861.95              21
#
#                 Farm Size  Product ID Product Name                 Brand  \
# Production Date
# 2021-12-27         Medium           5    Ice Cream           Dodla Dairy
# 2021-10-03          Large           1         Milk                  Amul
# 2022-01-14         Medium           4       Yogurt           Dodla Dairy
# 2019-05-15          Small           3       Cheese  Britannia Industries
# 2020-10-17         Medium           8   Buttermilk          Mother Dairy
#
# ...

# %% [markdown]
# #Impact of storage conditions and shelf life on the quality and availability of dairy products

# %%
storage_impact = df.groupby(['Storage Condition']).agg({'Quantity in Stock (liters/kg)':'sum'}).reset_index()

shelf_life_impact = df.groupby(['Shelf Life (days)']).agg({'Quantity in Stock (liters/kg)':'sum'}).reset_index()

# %% [markdown]
# The result is two new DataFrames (storage_impact and shelf_life_impact) that provide insights into the total quantity in stock for each unique value in these respective columns.

# %%
plt.figure(figsize=(10, 6))
plt.plot(shelf_life_impact['Shelf Life (days)'], shelf_life_impact['Quantity in Stock (liters/kg)'])
plt.xlabel('Shelf Life (days)')
plt.ylabel('Quantity in Stock (liters/kg)')
plt.title('Impact of Shelf Life on Quantity of Available Dairy Products')
plt.show()

# %% [markdown]
# In shelf life are showing that most of the products are sold in 10-20 days ans some are 30days, and quantity in stock high in 70000(liters/kg)

# %%
price_per_unit_impact = df.groupby(['Price per Unit (sold)']).agg({'Approx. Total Revenue(INR)':'sum'}).reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.plot(price_per_unit_impact['Price per Unit (sold)'],price_per_unit_impact['Approx. Total Revenue(INR)'])
plt.xlabel('Price per Unit (sold)')
plt.ylabel('Approx. Total Revenue(INR)')
plt.title('Impact of price unit on Approx. Total Revenue(INR)')
plt.show()

# %% [markdown]
# By the observation overal total revenue in INR is in between the range of 100000-120000 has highest.

# %%
monthly_avg_sales = df.groupby(['Date', 'Production Date'])['Quantity Sold (liters/kg)'].mean().reset_index()

# %%
monthly_sales = df.groupby('Date')['Quantity Sold (liters/kg)'].sum()
monthly_sales
# Out:
# Date
# 2019-01-01    1815
# 2019-01-02     445
# 2019-01-03     566
# 2019-01-04    1066
# 2019-01-05     384
#               ...
# 2022-12-24    1200
# 2022-12-25     747
# 2022-12-26     314
# 2022-12-27     679
# 2022-12-28    1562
# Name: Quantity Sold (liters/kg), Length: 1278, dtype: int64

# %% [markdown]
# By doing this we observe that in which date the quatity of product sold.

# %%
sns.jointplot(x='Quantity Sold (liters/kg)',y='Price per Unit (sold)',data=df)
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %% [markdown]
# The joint plot suggests the relationship between 'Quantity Sold (liters/kg)' and 'Price per Unit (sold), are in between 0-200 range has highest.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Assuming 'df' is your DataFrame and 'Sales Channel' is your target column
target_column = 'Sales Channel'

# Extract features (X) and target variable (y)
X = df.drop(target_column,axis=1)  # Drop the target column from features
y = df[target_column]

# Perform one-hot encoding for categorical variables
X_encoded = pd.get_dummies(X)

# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.25, random_state=150)

# Now you can proceed with training your model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(random_state=150)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=150)

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.36044362292051757

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#       Online       0.34      0.27      0.30       271
#       Retail       0.34      0.32      0.33       310
#    Wholesale       0.35      0.45      0.40       284
#
#     accuracy                           0.35       865
#    macro avg       0.34      0.35      0.34       865
# weighted avg       0.34      0.35      0.34       865

# %% [markdown]
# #Conclusion
#
# * Compare sales performance across different channels by visualizing total quantity sold, retail and wholesale are almost equal.
#
# * The shelf life time of overal dataset is 0-20 days , coming to the products amul is the highest.
#
# * Most of the products are purchased in chandigarh and delhi, delhi is the highest compared to others.
# *
